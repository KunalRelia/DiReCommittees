# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import matplotlib.pyplot as plt
import pandas as pd

# %%
file_path = 'runningtime-mupi'
df = pd.read_csv(file_path+'.csv', low_memory=False)

df_plot = df.pivot("Diversity", "Representation", "Proportion")
#fig = plt.figure()
X, Y = np.meshgrid([4,3,2,1,0], [0,1,2,3,4])
Z = df['Proportion'].values.reshape(X.shape)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='Reds', edgecolor='black')
ax.set_xlabel('\n$\mu$',fontsize=22)
ax.set_ylabel('\n$\pi$',fontsize=22)
ax.set_zlabel('\nrunning time (s)',fontsize=22, linespacing=1.5)

ax.set_xticks([4,3,2,1,0])
ax.set_yticks([0,1,2,3,4])
ax.set_zticks([0,750,1500])
ax.set_xticklabels([0,1,2,3,4])
ax.set_yticklabels([0,1,2,3,4])
ax.set_zticklabels([0,750,1500],verticalalignment='baseline')

ax.grid(False)

ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

#plt.rcParams['axes.linewidth'] = 1

ax.tick_params(labelsize=16)
ax.dist = 11

plt.tight_layout()
plt.savefig(file_path+'3d_v2.pdf')

# %%
file_path = 'timeout-mupi'
df = pd.read_csv(file_path+'.csv', low_memory=False)

df_plot = df.pivot("Diversity", "Representation", "Proportion")

X, Y = np.meshgrid([4,3,2,1,0], [0,1,2,3,4])
Z = df['Proportion'].values.reshape(X.shape)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='gray_r', edgecolor='black')
ax.set_xlabel('\n$\mu$',fontsize=22)
ax.set_ylabel('\n$\pi$',fontsize=22)
ax.set_zlabel('\n% timed out',fontsize=22, linespacing=1.5)

ax.set_xticks([0,1,2,3,4])
ax.set_yticks([0,1,2,3,4])
ax.set_zticks([0,50,100])
ax.set_zlim(0, 100)
ax.set_xticklabels([4,3,2,1,0])
ax.set_yticklabels([0,1,2,3,4])
ax.set_zticklabels([0,50,100],verticalalignment='baseline')

ax.grid(False)

ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

#plt.rcParams['axes.linewidth'] = 1

ax.tick_params(labelsize=16)
ax.dist = 11

plt.tight_layout()
plt.savefig(file_path+'3d_v4.pdf')

# %%
file_path = 'runningtime-mupi-Monroe'
df = pd.read_csv(file_path+'.csv', low_memory=False)

df_plot = df.pivot("Diversity", "Representation", "Proportion")
#fig = plt.figure()
X, Y = np.meshgrid([4,3,2,1,0], [0,1,2,3,4])
Z = df['Proportion'].values.reshape(X.shape)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='Reds', edgecolor='black')
ax.set_xlabel('\n$\mu$',fontsize=22)
ax.set_ylabel('\n$\pi$',fontsize=22)
ax.set_zlabel('\nrunning time (s)',fontsize=22, linespacing=1.5)

ax.set_xticks([4,3,2,1,0])
ax.set_yticks([0,1,2,3,4])
ax.set_zticks([0,750,1500])
ax.set_xticklabels([0,1,2,3,4])
ax.set_yticklabels([0,1,2,3,4])
ax.set_zticklabels([0,750,1500],verticalalignment='baseline')

ax.grid(False)

ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

#plt.rcParams['axes.linewidth'] = 1

ax.tick_params(labelsize=16)
ax.dist = 11

plt.tight_layout()
plt.savefig(file_path+'3d.pdf')

# %%
file_path = 'timeout-mupi-Monroe'
df = pd.read_csv(file_path+'.csv', low_memory=False)

df_plot = df.pivot("Diversity", "Representation", "Proportion")

X, Y = np.meshgrid([4,3,2,1,0], [0,1,2,3,4])
Z = df['Proportion'].values.reshape(X.shape)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='gray_r', edgecolor='black')
ax.set_xlabel('\n$\mu$',fontsize=22)
ax.set_ylabel('\n$\pi$',fontsize=22)
ax.set_zlabel('\n% timed out',fontsize=22, linespacing=1.5)

ax.set_xticks([0,1,2,3,4])
ax.set_yticks([0,1,2,3,4])
ax.set_zticks([0,50,100])
ax.set_zlim(0, 100)
ax.set_xticklabels([4,3,2,1,0])
ax.set_yticklabels([0,1,2,3,4])
ax.set_zticklabels([0,50,100],verticalalignment='baseline')

ax.grid(False)

ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

#plt.rcParams['axes.linewidth'] = 1

ax.tick_params(labelsize=16)
ax.dist = 11

plt.tight_layout()
plt.savefig(file_path+'3d.pdf')

# %%
file_path = 'Infeasibiility-constraints-borda'
df = pd.read_csv(file_path+'.csv', low_memory=False)

df_plot = df.pivot("Diversity", "Representation", "Proportion")

X, Y = np.meshgrid([0,1,2,3,4], [4,3,2,1,0])
Z = df['Proportion'].values.reshape(X.shape)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='Greens', edgecolor='black')
ax.set_xlabel('\n$\mu$',fontsize=22)
ax.set_ylabel('\n$\pi$',fontsize=22)
ax.set_zlabel('\nSatisfiability (%)',fontsize=22, linespacing=1.5)

ax.set_xticks([0,1,2,3,4])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels([4,3,2,1,0])
ax.set_zticks([65,70,80,90,100])

ax.grid(False)

ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

#plt.rcParams['axes.linewidth'] = 1

ax.tick_params(labelsize=16)
ax.dist = 11

plt.tight_layout()
plt.savefig(file_path+'3d_v2.pdf')

# %%
file_path = 'Infeasibiility-constraints-CC'
df = pd.read_csv(file_path+'.csv', low_memory=False)

df_plot = df.pivot("Diversity", "Representation", "Proportion")

X, Y = np.meshgrid([0,1,2,3,4], [4,3,2,1,0])
Z = df['Proportion'].values.reshape(X.shape)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='Greens', edgecolor='black')
ax.set_xlabel('\n$\mu$',fontsize=22)
ax.set_ylabel('\n$\pi$',fontsize=22)
ax.set_zlabel('\nSatisfiability (%)',fontsize=22, linespacing=1.5)

ax.set_xticks([0,1,2,3,4])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels([4,3,2,1,0])
ax.set_zlim(65, 100)
ax.set_zticks([65,70,80,90,100])

ax.grid(False)

ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

#plt.rcParams['axes.linewidth'] = 1

ax.tick_params(labelsize=16)
ax.dist = 11

plt.tight_layout()
plt.savefig(file_path+'3d_v2.pdf')
